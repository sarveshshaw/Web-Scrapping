# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
Links=[]
for i in range(1,32):
    url='https://www.fundoodata.com/citiesindustry/16/0/list-of-hotels-&-restaurants-companies-in-delhi-ncr?&pageno='+str(i)+'&tot_rows=621&total_results=621&no_of_offices=0'
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:50.0) Gecko/20100101Firefox/50.0'}
    source=requests.get(url, headers=headers)
    source.content
    soup=bs(source.content,'html.parser')
    results=soup.find_all('div',class_='search-result')
    for result in results:
        link=result.find('div',class_='heading')
        if link!=None:    
            Links.append(link.a['href'])

# %%
Name=[]
Add=[]
Phone=[]
for link in Links:
    page=requests.get(link)
    page.content
    subsoup=bs(page.content,'html.parser')
    subresult=subsoup.find('div',class_='search-page-right-pannel')
    if subresult!=None:
        name=subresult.find('div',class_='search-page-heading-red')
        Name.append(name.text.strip())
        no=subresult.find('div',class_='detail-line')
        if no!=None:
            ph=no.text.strip()
            no=ph.split("\n")
            number=no[0]
            Phone.append(number)
        else:
            Phone.append("NaN")
        tr=subresult.find('div',class_='search-page-heading-red').decompose()
        add=subresult.text.strip().split("\t")
        Add.append(add[0])

# %%
Name
# Out:
# ['Vivanta by Taj - Surajkund (*****) (Taj (IHCL))',
#  'Vivanta by Taj, Dwarka (Taj (IHCL))',
#  'Wave Hospitality Pvt Ltd ( Holiday Inn )',
#  'WelcomHeritage (ITC)',
#  'WelcomHotel Dwarka, New Delhi',
#  'WelcomHotel Sheraton, New Delhi (*****) (ITC)',
#  'World Square Hotel',
#  'Zone by the Park, Gurgaon',
#  '21 Gun Salute Restaurant',
#  'Aagami Hotel',
#  'Aakriti Hotels Pvt Ltd',
#  'Above N Beyond',
#  'Accord Hospitality Services Pvt Ltd ( Alliance Hotels & Resorts )',
#  'ACE Residency',
#  'ACG Hospitality Pvt Ltd(Hotel Signature Grand)',
#  'Ahimsa Food',
#  'Ahuja Residency Vista Woods',
#  'Ahuja Residency, Delhi',
#  'Airport Hotel',
#  'Almondz Hotel',
#  'Alpina Hotels & Suites',
#  'Ambient Resorts Pvt Ltd',
#  'Ambson View, Gurgaon',
#  'Amritara Hotels & Resorts Pvt Ltd',
#  'Angel Residency',
#  'Anila Hotels',
#  'Anmol Hotels Pvt Ltd',
#  'Apsara Banquet',
#  'Aria Hotels & Consultancy Services Pvt Ltd',
#  'Arshia Foodworks Pvt Ltd(Biryani Queen)',
#  'Ashok Convention Center',
#  'Ashok Country Resort',
#  'Atrium Lounge',
#  'Avalon Courtyard Residences and Suites',
#  'Balprada Hotels and Hospitality Services Pvt Ltd',
#  'Bamyan The Boutique Hotel',
#  'Bharat Guest House, Ghaziabad',
#  'Bougainvilla, Gurgaon',
#  'Brown Bread Bakery',
#  'Cabana Hotel',
#  'Cafe Delhi Heights',
#  'Casa2 Stays Pvt Ltd (FabHotels)',
#  'Caspia Hotel, New Delhi',
#  'Choice Hospitality India Pvt Ltd',
#  'City Hotel, New Delhi',
#  'Clarens Hotel',
#  'Cottage Yes Please',
#  'Dalmia Resorts International Pvt Ltd',
#  'Dayal Hotels & Resorts Pvt Ltd(Dayal Regency)',
#  'Dee Marks Hotel & Resorts',
#  'Deep House Hotel , Noida',
#  'Dhaba Estd 1986',
#  'Dineout (Times Internet Ltd) (Times)',
#  'Direct Hotels Pvt Ltd',
#  'Diva Restaurants',
#  'DLF Recreational Foundation Ltd (DLF)',
#  'DS Namah Hospitality Pvt Ltd (DS)',
#  'Dynasty Resort',
#  'Eddison Hotel',
#  'Ek Bar (Olive)',
#  'Gokul Residency',
#  'Golden Galaxy Hotels & Resorts',
#  'Golden Green Golf & Resorts Ltd',
#  'Golden Tulip - The Galgotias',
#  'Golden Tulip, Vasundhara',
#  'Grand Heritage Resort',
#  'Grand Venizia',
#  'Green Castle Delhi',
#  'Green View Residency',
#  'Guppy By Ai (Olive)',
#  'Habitare Boutique Inn',
#  'Hard Rock Cafe, Gurgaon',
#  'Heritage Village Resort & Spa, Manesar',
#  'Holiday Inn Express Gurgaon (Intercontinental Hotels Group ( IHG))',
#  'Holiday Inn Express New Delhi International Airport T3 (Intercontinental Hotels Group ( IHG))',
#  'Holiday Inn, Mayur Vihar (Intercontinental Hotels Group ( IHG))',
#  'Holiday Maker India Pvt Ltd',
#  'Holidaytrip.in',
#  'Homeystay',
#  'Hospitality Consultants India Pvt Ltd',
#  'Hotel 32nd Milestone',
#  'Hotel Adarsh Niwas',
#  'Hotel Africa Avenue, GK 1',
#  'Hotel Africa Avenue, Safdarjung Enclave',
#  'Hotel Airport City',
#  'Hotel Airport Residency',
#  'Hotel Akash Palace, Noida',
#  'Hotel Alantis',
#  'Hotel Alka Classic',
#  'Hotel Alpine Tree',
#  'Hotel Aman Deluxe',
#  'Hotel Aman International,New Delhi',
#  'Hotel Aman Palace',
#  'Hotel Amby Inn',
#  'Hotel Amrit Villa',
#  'Hotel Apra Deluxe',
#  'Hotel Arihant Inn, New Delhi',
#  'Hotel Ashoka International',
#  'Hotel Ashu Palace',
#  'Hotel Aster Inn',
#  'Hotel Atithi Palace',
#  'Hotel Aura',
#  'Hotel Avtar',
#  'Hotel Balsons Continental',
#  'Hotel Blessings',
#  'Hotel Bluestone',
#  'Hotel C Park INN',
#  'Hotel Capitol Hills',
#  'Hotel Caspia Pro, Greater Noida',
#  'Hotel Chaupal, Gurgaon',
#  'Hotel Citi International',
#  'Hotel City Castle',
#  'Hotel City Park, Airport',
#  'Hotel City Point',
#  'Hotel City Premier',
#  'Hotel Clark International',
#  'Hotel Classic Diplomat',
#  'Hotel Comfort Zone',
#  'Hotel Corporate Point',
#  'Hotel Corporate Suites',
#  'Hotel CrestInn',
#  'Hotel Crown Continental',
#  'Hotel Delhi 37, Delhi',
#  'Hotel Delhi Aerocity',
#  'Hotel Delhi Continental',
#  'Hotel Delhi Darbar',
#  'Hotel Delhi Empire Dx',
#  'Hotel Delhi Pride',
#  'Hotel Delight Inn, Delhi',
#  'Hotel Diplomat Residency',
#  'Hotel Durga International',
#  'Hotel Ekant, Faridabad',
#  'Hotel Emperor Palms',
#  'Hotel ERA',
#  'Hotel Excellent',
#  'Hotel Forest Green',
#  'Hotel Godwin Deluxe',
#  'Hotel Golden Tulip, Chattarpur',
#  'Hotel Golden Wings',
#  'Hotel Golf View',
#  'Hotel Golf View Suites',
#  'Hotel Good Times',
#  'Hotel Goodluck',
#  'Hotel Grand Park Inn',
#  'Hotel Grand Peepal',
#  'Hotel GRDINN',
#  'Hotel Green Lotus',
#  'Hotel Hanuwant Palace',
#  'Hotel Hari Piorko',
#  'Hotel Haut Monde',
#  'Hotel Hi Life',
#  'Hotel Honeymoon Inn, Delhi',
#  'Hotel Imperial Palace,Faridabad',
#  'Hotel Impress',
#  'Hotel International Inn',
#  'Hotel IVORY 32',
#  'Hotel Ivory Palace',
#  'Hotel Jageer Palace',
#  'Hotel JPS Residency',
#  'Hotel Metro Heights',
#  'Hotel Metro View',
#  'Hotel Mohan International',
#  'Hotel New King',
#  'Hotel Noratan Palace',
#  'Hotel Orchid Garden',
#  'Hotel Oscar',
#  'Hotel Pablas International',
#  'Hotel Palace Heights',
#  'Hotel Park Residency',
#  'Hotel Parkway Deluxe',
#  'Hotel Parth Inn',
#  'Hotel Pearl Plaza',
#  'Hotel Picasso,Prive',
#  'Hotel Pitrashish Premium',
#  'Hotel Prime Balaji Deluxe',
#  'Hotel Prince International',
#  'Hotel Prince Palace',
#  'Hotel Private Affair',
#  'Hotel Rahul Palace',
#  'Hotel Rajdeep',
#  'Hotel Rajdhani Palace',
#  'Hotel Rajmandir',
#  'Hotel Regent Continental',
#  'Hotel Regent Grand',
#  'Hotel Relax Inn, Delhi',
#  'Hotel Relax Palace',
#  'Hotel Rousha Inn',
#  'Hotel Roxy Dx',
#  'Hotel Royal Castle',
#  'Hotel Royal Park(Royal Park Hospitality Pvt Ltd)',
#  'Hotel Royal Star',
#  'Hotel Royale Paradise',
#  'Hotel Sahara International Deluxe',
#  'Hotel Sarthak Palace',
#  'Hotel Sarthi',
#  'Hotel Sewa Grand',
#  'Hotel Shimla Heritage',
#  'Hotel Shiva Intercontinental',
#  'Hotel Shyama International, New Delhi',
#  'Hotel Silver Leaf',
#  'Hotel Singh International',
#  'Hotel Sita International',
#  'Hotel Sri Nanak Continental',
#  'Hotel Star',
#  'Hotel Star Paradise (Star Group of Hotels)',
#  'Hotel Sun City',
#  'Hotel SunCourt Corporate',
#  'Hotel Sundeep Inn',
#  'Hotel Sunshine',
#  'Hotel Sunstar Heritage',
#  'Hotel Sunstar Residency',
#  'Hotel Surya International',
#  'Hotel Swagat Palace',
#  'Hotel Tara Palace, New Delhi',
#  'Hotel The Cameron',
#  'Hotel The Raj',
#  'Hotel Today International',
#  'Hotel Tourist Deluxe',
#  'Hotel Tourist.',
#  'Hotel Transit, Delhi',
#  'Hotel Veer Palace',
#  'Hotel Venus',
#  'Hotel Waves',
#  'Hotel White House Continental',
#  'Hotel Woodland Deluxe',
#  'Hotel Yug Villa',
#  'Hyphen Hotel Noida',
#  'ICS Foods & Hospitality Services Pvt Ltd',
#  'Imperfecto',
#  'Indian Accent',
#  'Indraprastha Hotel',
#  'Infinity Resorts',
#  'Jasper Hotel Representation',
#  'Johnny Rockets India',
#  'Jukaso Inn, New Delhi',
#  'Justa - The Residence Panchsheel Park',
#  'Justa Atrio',
#  'Justa The Residence, Gurgaon',
#  'Jyoti Mahal',
#  'K Hotel, Faridabad',
#  'Kairali Ayurvedic Health Resort Pvt Ltd',
#  'Karim Hotels Pvt Ltd',
#  'Karon Hotels',
#  'Kastor International',
#  'Konark Corporate Suites',
#  'La Sapphire Hotel',
#  'La Wisteria Boutique Hotel',
#  'LaSagrita Tourist Home',
#  'Le Crescent',
#  '',
#  'Lemon Tree Premier, Leisure Valley 2 (Lemon Tree Hotels)',
#  'Liv Inn',
#  'Mahalakshmi Palace',
#  'Manan Regency',
#  'Mandakini Palace Hotel',
#  'Mantra Amaltas',
#  'Mayur Hotel, New Delhi',
#  'Mehar Wing Services Pvt Ltd (Pinch Of Spice)',
#  'Moti Mahal Delux',
#  'Mukut Hotels & Resorts Pvt Ltd',
#  'Mumtaz Hotel, New Delhi',
#  'National Restaurant Association of India',
#  'Nehru Place Hotels And Real Estate Pvt Ltd (ERA)',
#  'Nityaz Residency',
#  'Noshi',
#  'Oodles Hotel, Chattarpur',
#  'OYO 311 City Stay Hotel',
#  'Parfait Hospitality Pvt Ltd',
#  'Park Ascent',
#  'Pearls Regency Restaurant & Bar',
#  'Pizza Key',
#  'Prakash Continental',
#  'Promach Hospitality Pvt Ltd',
#  'Pulse Impulse',
#  'Punjab Grill Tappa',
#  'QBA Bar & Restaurants',
#  'Qutub Residency',
#  'Rama Inn',
#  'Ramada by Wyndham, Pitampura',
#  'Red Carpet Hotels , Noida',
#  'Red Fox Hotel, Gurugram (Lemon Tree Hotels)',
#  'Red Maple',
#  'Relax Suites',
#  'Residency Resorts Pvt Ltd',
#  'RK Villa',
#  'Roop Hotels & Resorts Pvt Ltd',
#  'Rosewood Apartment Hotel',
#  'Royal China',
#  'Rudrakshaa',
#  'S Bar & Restaurant',
#  'Saffron Kiran',
#  'Samak Nature Resorts Pvt Ltd',
#  'SAMHI Hotels Ltd',
#  'Sands Inn, Gurgaon',
#  'SARA Hospitality',
#  'Sarovar Portico Naraina, New Delhi',
#  'SavoySuites , Greater Noida',
#  'SavoySuites, Manesar',
#  'Sehgal Infrastructures Ltd (Wet n Wild)',
#  'Shanti Adventure Tours Pvt Ltd',
#  'Shanti Home, New Delhi',
#  'Shreyans Inn',
#  'Shudh Hospitality Pvt Ltd',
#  'SilverStone Hotels Pvt Ltd',
#  'Siris 18 Gurgaon',
#  'Sleepy Owl Coffee',
#  'SodaBottleOpenerWala (Olive)',
#  'South Indian Hotel',
#  'Starlit Suites LLP',
#  'Stately Suite Pvt Ltd',
#  'Sunrydge Kila Resorts Pvt Ltd',
#  'Sunstar Hospitality',
#  'Surbee Resorts',
#  'Swarn Hotels LLP',
#  'Tandoori Village Restaurant',
#  'Tasanaya Hospitality Pvt Ltd',
#  'Taurus Hotel & Conventions',
#  'Taurus Sarovar Portico, New Delhi (Sarovar)',
#  'Tavisha Villa Gurgaon',
#  'Tavisha Villa Hotel , Noida',
#  'The Allure Hotel, New Delhi',
#  'The Baithak Restaurant',
#  'The Claire- Hotel',
#  'The Corus Hotel',
#  'The Eden Hotel',
#  'The Federation of Hotel and Restaurant Associations of India',
#  'The Fern Residency, Gurgaon (****)',
#  'The Gold Inn Hotel',
#  'The Golden Dragon, Dwarka',
#  'The Golden Dragon, Gurgaon.',
#  'The Golden Dragon, Lajpat Nagar II',
#  'The Golden Dragon, Noida',
#  'The Golden Dragon, Panchsheel Park',
#  'The Golden Dragon, Preet Vihar',
#  'The Golden Dragon, Rajouri Garden',
#  'The Golden Dragon, Sohna Road, Gurgaon',
#  'The Golden Dragon, Vasant Vihar',
#  'The Golden Gate Residency',
#  'The Zion Residency Inn',
#  'Tiger Resorts Pvt Ltd',
#  'Treebo Conclave Riviera',
#  'Treehouse Queens Pearl, Gurgaon',
#  'Trillion Hotel',
#  'Tulip INN , New Delhi (Sarovar)',
#  'UMAK Hospitality Pvt Ltd ( The Great Kabab Factory )',
#  'Umrao Hotels and Resorts Pvt Ltd',
#  'V M Residency',
#  'V Resorts',
#  'Vaishree Boutique Hotels Pvt Ltd',
#  'Vanson Villa Hotel',
#  'Vatika Grand',
#  'Vibe Hotel',
#  'VidKris Group',
#  'VW Cuisines & Concepts Pvt Ltd (Fio)',
#  'WelcomHeritage Haveli Dharampura (ITC)',
#  'Welworth Hotels',
#  'Wood Castle',
#  'Xperience India Hotels & Resorts Pvt Ltd']

# %%
Add
# Out:
# ['Address - Shooting Range Road',
#  'Address - Sector 21 Metro Station Complex,',
#  'Address - Asset Area 12',
#  'Address - 25, Shopping Centre, Basant Lok',
#  'Address - Plot No.3, Sector-10,',
#  'Address - District Centre, Saket',
#  'Address - Mohan Nagar T-point',
#  'Address - 285 - 286 Millennium City Center, Sector 29',
#  'Address - SCO 35-36 First Floor Leisure Valley Road',
#  'Address - 104 Babar Road,',
#  'Address - 2nd Floor, 30, Community Center',
#  'Address - A 22/23, First Floor, Kirti Nagar',
#  'Address - 108, Tamoor Nagar, New Friends Colony',
#  'Address - C-233 Greater Kailash-1',
#  'Address - 1A, Sub District center,',
#  'Address - A - 2 ,38 2ND Floor',
#  'Address - A-191, GreenWood City,Sector -45,',
#  'Address - 193 Golf Links',
#  'Address - Opp. IGI Airport (T-1)',
#  'Address - 4/3 East Patel Nagar Near Metro',
#  'Address - E 506 GK-II',
#  'Address - 201, Local Shoping COmplex, Deraal Nagar',
#  'Address - 108, Akashneem Marg,DLF Phase-2',
#  'Address - 32/7 Plot No 09',
#  'Address - 39C Knowledge Park 1',
#  'Address - A - 15, Naraina Vihar',
#  'Address - 8180/6 Arakashan Road, Pahar Ganj',
#  'Address - A-1/20 B Paschim Vihar',
#  'Address - 6th Floor, Aria Towers, Jw Marriott, IGI Airport',
#  'Address - M-219, L G Floor, Orchid Island',
#  'Address - Diplomatic Enclave, 50-B Chanakayapuri',
#  'Address - 30, Rajokri Road, Kapashera',
#  'Address - Maulana Mohammad Ali Jauhar Marg',
#  'Address - Empire Estate, M. G. Road, Sultanpur',
#  'Address - Unit No.-6, Upper Ground Floor,',
#  'Address - 6 A, Ring Road,',
#  'Address - B-1, Surya Nagar',
#  'Address - 1325, Sector-43,',
#  'Address - A Main Bazar, opposite Khanna Cinema',
#  'Address - R23 Greater Kailash 1',
#  'Address - 121 –123, 1st floor, Cross Point Mall',
#  'Address - Enkay Towers, Udyog Vihar Industrial Area Phase 5',
#  'Address - District Center,',
#  'Address - Building No. 9, Tower B 11th Floor, DLF Cyber City',
#  'Address - A-3 Pamposh Enclave, GK-1',
#  'Address - 363-364, Sector-29',
#  'Address - 1843-44, Laxmi Narayan Street',
#  'Address - 4, Scindia House, Connaught Place',
#  'Address - B-718, Sushant Lok,',
#  'Address - Near Radisson Hotel,Adjoining Shiv Murti,National Highway-8,',
#  'Address - B - 21 Sec 56 Near D. A. V. School',
#  'Address - Shop No. 111, 1st Floor, Cyber Hub',
#  'Address - Plot No. 391, Udyog Vihar, Phase â€“ III',
#  'Address - 301, Ansal Classique Tower',
#  'Address - M-8A M Block Market',
#  'Address - DLF City Club, (Opp. Galleria Market), DLF City, Phase IV',
#  'Address - A-85, Sector â€“ 2',
#  'Address - 252/A,1st floor, Sahapur Jat,',
#  'Address - 293/3 Near Sec-14',
#  'Address - D 17, First Floor, Defence Colony,',
#  'Address - C- 928, Palam Extension,',
#  'Address - National Highway 2, Delhi Mathura Road,',
#  'Address - 5th Floor,Global Foyer',
#  'Address - SCO No. 4, Sector 23-A,',
#  'Address - C-5 Sector-18, Vasundhara',
#  'Address - R-4, Sec-20, opp-metro pillar no -898',
#  'Address - 6 Bhamsha Marg Opp Kirpal Bagh',
#  'Address - 1418-1427 Lothian Road Kashmere Gate',
#  'Address - Pratap Bhawan, C-Block, Near Electricy',
#  'Address - 28, Main Market, Lodhi Colony,',
#  'Address - H 34/5, DLF Phase-1',
#  'Address - Unit No. 4/5/104/105',
#  'Address - NH 8 Manesar',
#  'Address - Good Earth City Centre, Sector 50,',
#  'Address - Level 5, Terminal 3,',
#  'Address - 13A Mayur Vihar, District Centre',
#  'Address - R-583 ,New Rajinder Nagar',
#  'Address - 216-A/5, Gautam Nagar Rd, Block B, Neeti Bagh',
#  'Address - 325 ,Sec 21 A',
#  'Address - 1504,ocus Quantum',
#  'Address - NH-8 Sector 15,',
#  'Address - 483, Ist Floor, Haider Kuli Corner',
#  'Address - B-104, Greater Kailash - 1',
#  'Address - A-2/14, Safdarjung Enclave',
#  'Address - A 11 Road no 1 N.H.8 Near I.G.I',
#  'Address - Dwarka Link Road Off NH 8',
#  'Address - D 194, Sector 51',
#  'Address - 337 AP , Ananad farmhouse road,',
#  'Address - P-16, Connaught Circus',
#  'Address - A 65 Mahipalpur National Highway 08',
#  'Address - A-30/31, Vishal Enclave,',
#  'Address - 4555-56, Main Bazaar, Paharganj',
#  'Address - A-40,Vishal Enclave, Rajouri Garden, Opp.TDI Mall',
#  'Address - M-13,',
#  'Address - 15/10169 W.E.A Gurudwara Road',
#  'Address - 12A/35, W.E.A., Karol Bagh',
#  'Address - 7a/69, WEA, Channa Market Karol Bagh',
#  'Address - 3382 Christion Colony D B Gupta Road',
#  'Address - 12A 34 W.E.A. Karol Bagh',
#  'Address - 1078-80, Hardhyan Singh Rd,',
#  'Address - 50, Dr. Shubhash',
#  'Address - 31 Arakashan Road Paharganj',
#  'Address - 3452 Desh Bandhu Gupta Road, Pahar Ganj',
#  'Address - 8/1 East Patel Nagar',
#  'Address - 5202-5206, Basant Road',
#  'Address - CC 24 Nehru Enclave Opp Paras Cinema',
#  'Address - 1042 / 15, Abdul Rahman Road',
#  'Address - C-42, Greater',
#  'Address - Wegman s Business Park Plot No3',
#  'Address - 303/2, Sector-14,',
#  'Address - 8/20, WEA, Karol Bagh',
#  'Address - 1100/12-13,  Hari Singh Nalwa Street',
#  'Address - NH 8 Kapashera',
#  'Address - Shop No -165/2 Near Bus Stand & Opp. Bus Stand Gat',
#  'Address - Plot no.- 6303,',
#  'Address - Saraswati Marg, Block 5',
#  'Address - A-4, NH-8, Near IGI Airport,',
#  'Address - E-586, Greater Kailash-2',
#  'Address - A-2/7,Safdarjung Enclave,',
#  'Address - C-30/4 Sector -62',
#  'Address - 4/27 W.E.A. Saraswati Marg',
#  'Address - 59/30 New Rotak Road',
#  'Address - A-147, National Highway No. 8',
#  'Address - 104/2/2, M. R. Complex',
#  'Address - 8218-19 Arakashan Road,',
#  'Address - 15A/26, W.E.A, Ajmal Khan Road',
#  'Address - 8678, Arakashan Road',
#  'Address - 12A / 28 W.E.A Saraswati marg',
#  'Address - 336, 40-41, Near Bank Of India',
#  'Address - 56, Ring Road Lajpat Nagar-III',
#  'Address - 8715, Desh Bandhu Gupta Road , Pahar Ganj',
#  'Address - SCF 12, 13 & 14, Sector 17 Market',
#  'Address - 15 A 7  W.E.A Karol Bagh',
#  'Address - A 247/1 Mahipal Pur Extn',
#  'Address - C-12, Panchsheel Enclave',
#  'Address - 24 Siri Fort Road',
#  'Address - 8501/15 Arakshan Road',
#  'Address - 242-245 Fatehpur Beri',
#  'Address - 135-136, NR New Delhi Railway Station',
#  'Address - 14/1 Opp. Botanical Garden Metro Station',
#  'Address - Plot No. 630, Sector – 43,',
#  'Address - 8/7, W.E.A. Karol Bagh',
#  'Address - A-103, Road No.4,',
#  'Address - 1041/17 Abdul Rahman Road Naiwalan',
#  'Address - 4/1 W.E.A Saraswati Marg',
#  'Address - H 20 B Kalkaji Main Road',
#  'Address - 91, Bijwasan Rd, Kapas Hera Extension',
#  'Address - A-31/2, Mahipalpur Extn',
#  'Address - 4775, Main Bazaar,',
#  'Address - Sector 15, Exit no - 9',
#  'Address - 8280, Arakashan Road,',
#  'Address - 534 patparganj, indl. area',
#  'Address - 57, Neelam Bata Rd,AC Nagar,',
#  'Address - A-25 Vasant Kunj Road Mahipalpur',
#  'Address - A-78, National Highway No. 8',
#  'Address - C-32, Greater Kailash-1',
#  'Address - 14A/27, W.E.A Channa Market,',
#  'Address - C-6/1, Mansarover Garden,',
#  'Address - 6, Hargovind Enclave,  Karkardooma',
#  'Address - 8/35, W. E. A., Padam Singh Road, Karol Bagh',
#  'Address - 17A/3, W.E.A, Karol Bagh',
#  'Address - 2, Arakashan Road,',
#  'Address - T-279, General market',
#  'Address - A 27 Road No 1 Mahipalpur Extn',
#  'Address - 51/1, Desh Bandhu Gupta Road,',
#  'Address - C-2/11, Safdurjung Developement Area',
#  'Address - 12 A / 22, W.E.A Saraswati Marg, Karol Bagh',
#  'Address - D - 26/28, Connaught Place',
#  'Address - D-1 , Green Park, Aashirwad Building',
#  'Address - 8591 Qutab Road Near New Delhi Railway Station',
#  'Address - C-1, Govindpuram,',
#  'Address - 2348/2350 Raj Guru Road',
#  'Address - A-14 Narayana Vihar',
#  'Address - 59/36, New Rohtak Road',
#  'Address - 8574 Arakashan Road,',
#  'Address - 14A/24 W.E.A Channa Market',
#  'Address - Near R.K.Ashram Marg',
#  'Address - C-2, Greater Kailash 1',
#  'Address - 5/3, W.E.A. Karol Bagh, Ajmal Khan Road',
#  'Address - 4-B, Bharat Nagar, New Friends Colony',
#  'Address - 4196 Tel Mandi Opp New Delh Rly',
#  'Address - 45 Neelam Bata Road',
#  'Address - 4/73 Saraswati Marg - Karol Bagh,',
#  'Address - 2/6 East Patel Nagar Opp. Metro Pillar No 167',
#  'Address - 35, South Patel Nagar',
#  'Address - Relax Palace 12A/9 W.E.A',
#  'Address - D-81, Kaushambi Metro Station,',
#  'Address - 2261-64, Rajguru Road,',
#  'Address - D-616 Chittaranjan Park',
#  'Address - SK-II/209, Indirapuram',
#  'Address - Plot No 9 Sector 10',
#  'Address - Y-349C Sec 12 Next To H.P Petrol Pump',
#  'Address - 3162/63 Sangtrashan Road',
#  'Address - 14A/34, W. E. A., Karol Bagh',
#  'Address - Gate No 3, A Block, Sector 53',
#  'Address - 12/4 NH2 Sarai Khwaza ,',
#  'Address - 7A/36  W.E.A. Channa Market, Karol Bagh',
#  'Address - 8478/13 Arakashan Road, Ram Nagar | Ram Nagar',
#  'Address - C-5/32, Safdarjung Development Area,',
#  'Address - A- 66, Sector 51',
#  "Address - 4/64, Padam Singh Road,Near Mc'Donald",
#  'Address - 3/10, D.B. Gupta Road,',
#  'Address - 2222 Hardhian Singh Road',
#  'Address - A 288 National Highway No. 8',
#  'Address - 4582, Main Bazar,',
#  'Address - 11 A/34, W. E. A., Karol Bagh',
#  'Address - 6A/67, WEA Channa market,',
#  'Address - F3/22, Vasant Vihar',
#  'Address - 17-B 21 Dev Nagar Desh Bandhu Gupta Road',
#  'Address - 8A/43, W.E.A. Channa Market, Karol Bagh',
#  'Address - 8A/50 W.E.A. Channa Market',
#  'Address - 4/33, W E A, Saraswati Marg,',
#  'Address - F-2, Desh Bandhu Gupta Road,',
#  'Address - 419, Esplanade Road,',
#  'Address - 92, Pocket-1, Jasola',
#  'Address - 8495, Arakashan Road',
#  'Address - 3/11, D. B. Gupta Road,',
#  'Address - 7361, Ram Nagar, Qutub Road, Pahar Ganj',
#  'Address - 7361, Ram Nagar, Qutub Road,',
#  'Address - A-58, Road Number 4, National Highway No 8',
#  'Address - B2/3, Africa Avenue Road,',
#  'Address - A-block, Mahipalpur Extn. National Highway-8',
#  'Address - A 272 Mahipalpur Extn National Highway',
#  'Address - 14-A/4 W.E.A. Channa Market',
#  'Address - 8235/6, Multani Dhanda, Arakashan Road',
#  'Address - 7A/14 WEA Channa Market Karol Bagh',
#  'Address - Supertech Building C-45 Sec62',
#  'Address - 09/910, Emaar Palm Square, Sector',
#  'Address - 1 A/1, Hauz Khas Village, Near Deer Park, Hauz Kha',
#  'Address - The Lodhi, Lodhi Road,',
#  'Address - 17A/54, Gurudwara Road, Opposite Jessa Ram Hospital',
#  'Address - C-32,Sushant Lok,Phase-1',
#  'Address - 1st Floor',
#  'Address - 206, Rectangle One,',
#  'Address - 50, Sunder Nagar',
#  'Address - S-362, Panchsheel Park',
#  'Address - Off NH-8,',
#  'Address - NR-40 DLF phase III',
#  'Address - 2488-90 Nalwa Street (behind Imperial Cinema)',
#  'Address - Plot No. 2, Huda Market , Sector 31',
#  'Address - D - 130, Block D, Ambedkar Colony Mehrauli',
#  'Address - House No. 16, Jama Masjid, Gali Kababian,',
#  'Address - 61 Ring Road,',
#  'Address - B-216, Chitranjan Park,',
#  'Address - Block-C2/68,Sushant Lok 1',
#  'Address - A-23, NH-8,',
#  'Address - 52, Sector-12 B,',
#  'Address - 14, Sunder Nagar',
#  'Address - Plot No. - 14A, Mall Road,',
#  'The updated information of this company is currently unavailable. For other companies please visit Advance Search.\n',
#  'Address - 43-47, Sector-29,',
#  'Address - E 14 Naraina Vihar',
#  'Address - 68, Mahalakshmi Palace Hotel',
#  'Address - F - 2550E, Palam Vihar',
#  'Address - 8/29 W.E.A., Abdul Aziz Road,',
#  'Address - 23 Friends Colony (W)',
#  'Address - 51, Aara Kashan Road,',
#  'Address - F-90, Vishal Enclave, Dist. Centre,',
#  'Address - 10/48 Diplomatic Enclave',
#  'Address - B5/1,II Floor,Sector-4,Rohini',
#  'Address - M-55 First Floor  Lajpat Nagar - II',
#  'Address - 4th Floor PHD House 4/2 Institutional Area',
#  'Address - 8th floor, Eros Corporate Tower, Nehru Place',
#  'Address - A-14 Sector -50 Near City Centre Metro Station',
#  'Address - 23 community Centre Zamrudpur',
#  'Address - 759  762, Main Road, Chattarpur',
#  'Address - Main Road  Sec-22',
#  'Address - Office No-9, 2nd Floor, Wedding Mall',
#  'Address - Plot no. 126 Noida-Khoda Road',
#  'Address - R-253, Block-1 Ganga Shopping complex',
#  'Address - HD-119, Sector-135, RWA Duplex Villa',
#  'Address - Wazirpur Press Area',
#  'Address - 174-E, Patparganj, 1st Floor, Mayur Vihar',
#  'Address - 2 - Ring Road, Kilokri,',
#  'Address - 19, Ground Floor, Cyber Hub',
#  'Address - E - 42 / 43, Inner Circle, Connaught Place',
#  'Address - 81, Adchini, Sri Aurobindo Marg,',
#  'Address - 4, Arakashan Road,',
#  'Address - Plot No 10 Road Number 42',
#  'Address - Bs- 31, Sec- 70 , Oppsite- Cleo County Tower',
#  'Address - Ullavas, Urban Complex,',
#  'Address - 49 Amrit Nagar',
#  'Address - Retailex-1A, 10 Com-1A, Sector-10, Vasundhara',
#  'Address - Usi Premises, Opp Signus Enclave, Rao Tula RAM Mg, Shankar Vihr',
#  'Address - Sec-52',
#  'Address - 801 Skylark Building 60 Nehru Place',
#  'Address - Sector 14 Market Road',
#  'Address - 16th Floor, Eros Corporate Tower,',
#  'Address - Metro Station Gaur Ganga 2, Phase 1',
#  'Address - N-17 , N-Block Market,',
#  'Address - NH-2, 12/6, Sector-35,',
#  'Address - Damdama Village, Near Damdama Lake',
#  'Address - 14th Floor, Building 10',
#  'Address - Plot No.188, Sector - 56,',
#  'Address - Opposite Sector B, Pocket 4, Aruna Asaf Ali Marg',
#  'Address - A-9, Naraina Vihar',
#  'Address - Ansal Plaza 1-C',
#  'Address - R-75, Sector 1,',
#  'Address - 45-Milestone, Sector 78, Naurangpur, N.H.-8, Jaipur Highway',
#  'Address - A5, FIEE Complex, Okhla Phase 2,',
#  'Address - A-1, 300, Janakpuri,',
#  'Address - B-2/5, Safdarjung Enclave  Africa Avenue Marg',
#  'Address - 17A/32, W.E.A Karol Bagh Near Metro Pillar No 98,',
#  'Address - 13A/22,channa Market,',
#  'Address - 18 Siris Road,',
#  'Address - 145/1, Shahpur Jat, Siri Fort,',
#  'Address - Shop no. 3, CyberHub, Near Building no 8,',
#  'Address - 10211, Padam Singh Road, (Ajmal Khan Road), Karol Bagh',
#  'Address - S435, GK2',
#  'Address - A-151a, Sushant LOK Phase 1',
#  'Address - Seven Style Mile, Mehrauli',
#  'Address - 7A/17 W.E.A.,Channa Market, Karol Bagh',
#  'Address - 2459/9, Beadonpura, Ajmal Khan, Karol Bagh',
#  'Address - 15A/33, W.E.A. Ajmal Khan Road, Karol Bagh',
#  'Address - 307, Great India Place, Spoon The Food Court,3RD FLR',
#  'Address - 14/13, Vasant Vihar',
#  'Address - IGI Airport Road, N.H-08, Mahipalpur extn',
#  'Address - IGI Airport Road, N.H-08, Mahipalpur Extn',
#  'Address - H-34/18, DLF Phase-1',
#  'Address - A 212 Sector 43',
#  'Address - R-57, Greater Kailash -1',
#  'Address - 41 East Patel Nagar Market',
#  'Address - Site No. 24 Sector-31',
#  'Address - B-49, Connaught Place',
#  'Address - G-43,Kalindi Kunj Jasola',
#  'Address - B-82, 8th Floor Himalaya House, 23 Kasturba Gandhi Marg',
#  'Address - 290/291 Sector-29',
#  'Address - 12A/24 WEA, Saraswati Marg Karol Bagh',
#  'Address - 301, Sector 4, Plot-12',
#  'Address - LG 46A, DT Mega Mall Ground Floor,DLF City Phase I',
#  'Address - Lajpat Nagar II',
#  'Address - Sector 44',
#  'Address - Panchshila Park RBI Colony',
#  'Address - Shop No. 25, 27,28 V3S Mall, Preet Vihar',
#  'Address - shop no 25 central market punjabi bagh',
#  'Address - Spazedge Mall, Tower A Ground Floor Sohna Road',
#  'Address - C-2, Main Market Vasant Vihar',
#  'Address - A-48, Sector -26',
#  'Address - V 39/14 , DLF',
#  'Address - 206, Rakeshdeep, 11 Commercial Complex',
#  'Address - A- 20 Kailash Colony',
#  'Address - Opp. District Courts, Rajiv Chowk',
#  'Address - 218/3/3 MG Road',
#  'Address - Plot no.# IC, Sub District Centre,',
#  'Address - Corporate floor, Radisson Hotel',
#  'Address - National Highway - 8',
#  'Address - 50, Main Road Masudpur',
#  'Address - B&B Genesis, A 2/3, Ground Floor',
#  'Address - T - 11/9, DLF - Phase - III',
#  'Address - 2531, Chuna Mandi Near Mother Dairy',
#  'Address - Sector 29,',
#  'Address - 12/7 Mathura Road, Just after Toll Plaza',
#  'Address - VidKris HOUSE  B-91, Panchsheel Vihar',
#  'Address - Epicuria Mall,',
#  'Address - 2293, Gali Guliyan',
#  'Address - 7, Regal Building Behind Regal Cinema',
#  'Address - 8A/7G, W.E.A. Channa Market,',
#  'Address - F 210 D Old M B Road Lado Sarai']

# %%
Phone
# Out:
# ['(0129) 4190000',
#  '(011) 66003000 ',
#  '(011) 42222000 ',
#  '(011) 46035500 ',
#  '(011) 42229222 ',
#  '(011) 42661122 ',
#  '(0120) 4667777',
#  '(0124) 4987000 ',
#  '(0124) 4898344 ',
#  '(011) 48481234',
#  'aakritihotels.com',
#  '(011) 42036299',
#  '(011) 26936975 26936974 ',
#  '(011) 46556829 46536733 ',
#  '(011) 49394939 ',
#  '(011) 40574993',
#  'ahujaresidency.com',
#  '(011) 24622255 24611027 ',
#  '(011) 25675262 25675716 ',
#  '(011) 45580000 ',
#  '(011) 40405555 ',
#  '(011) 47650064 ',
#  '(0124) 4051881',
#  '(011) 66617837 40752203 ',
#  'angelresidency.com',
#  '',
#  '(011) 45785777 ',
#  'www.apsarabanquet.in',
#  '(011) 41597325 45212121',
#  'www.biryaniqueen.com',
#  '(011) 26110101 26116161 ',
#  '(011) 25064590 ',
#  '(011) 26835070 ',
#  '(011) 42224111 ',
#  '',
#  '(011) 46579791 46579797 ',
#  '(0120) 4113857',
#  'www.bogainvilla.com',
#  'www.bakerybreadbrown.blogspot.in',
#  '(011) 41015555',
#  '(0124) 4229797 ',
#  '(0124) 4554242 ',
#  '(011) 39813444 ',
#  '(0124) 4567100 ',
#  '(011) 40765525',
#  '(0124) 4929292 4929205 ',
#  '(011) 43081400 23562100 ',
#  '(011) 23314001 ',
#  '(0124) 4303000 ',
#  '(011) 25060721 ',
#  '(0120) 4348988 4216364 ',
#  'www.dhaba1986.com',
#  'www.dineout.co.in',
#  '(011) 45137000 ',
#  '(011) 41637858 ',
#  '(0124) 4129101 4129100 ',
#  '(0120) 4032200 ',
#  'www.dynastyresort.com',
#  '(0124) 4266677 ',
#  '(011) 41648844 ',
#  '(011) 45665223 ',
#  'www.goldengalaxy.in',
#  'www.gggrl.com',
#  '(0124) 4900900 ',
#  'vasundhara.goldentulip.com',
#  'www.grandheritageresort.com',
#  '(011) 49222777 ',
#  '(011) 23972820 23914735 ',
#  '',
#  '(011) 24690005 ',
#  '(0124) 4054096 ',
#  '(0124) 4949630 ',
#  '(0124) 2871500 ',
#  '(0124) 6685555 ',
#  '(011) 45252000 ',
#  '(011) 41105555 ',
#  '(011) 45129962',
#  'www.holidaytrip.in',
#  '',
#  'www.hcipl.com',
#  '(0124) 4870400 ',
#  '(011) 23987576 ',
#  'www.hotelafricaavenue.com',
#  '(011) 46037777 ',
#  '(011) 46528000 ',
#  '(011) 47122226 47122225 ',
#  '',
#  '(0124) 4274349',
#  '(011) 23344328',
#  'www.hotelalpinetree.co.in',
#  '(011) 25934555 25413980 ',
#  '(011) 41698873 ',
#  '',
#  '(011) 45633048 45633049 ',
#  '',
#  '(011) 47323421 47323422',
#  '(011) 45059046',
#  '(011) 28727023 28727024',
#  '(011) 25863421 25863422',
#  '(011) 43738880 43738881 ',
#  '(011) 23245546 ',
#  '(011) 43080550 43080551 ',
#  '(011) 23580009 ',
#  '(011) 45147001',
#  '(011) 23587484 ',
#  '(011) 46085270 ',
#  '(011) 41557382',
#  '(011) 40571655',
#  '(0120) 6651711 ',
#  '',
#  '(011) 28750022 28750077 ',
#  '(011) 28757793 28753705 ',
#  '(011) 42320101 ',
#  '(0124) 2323838',
#  '(0124) 4375652 ',
#  'hotelclarkindia.com',
#  '(011) 40419900 ',
#  '(011) 47155555 29222345 ',
#  '(011) 41759000 ',
#  'corporatesuitesnoida.com',
#  '(011) 25760224 25760225 ',
#  '(011) 28711911',
#  '(011) 26784021 26784444 ',
#  '(011) 42198498 ',
#  '(011) 43586100 ',
#  '(011) 25752450 ',
#  '(011) 23532343 23522343',
#  '(011) 45709999 ',
#  'www.delightinn.com',
#  '(011) 41029505 ',
#  '(011) 23521363',
#  '(0129) 4071291 ',
#  '(011) 45064928 ',
#  'www.stargroupofhotels.in',
#  '',
#  '(011) 26252425 ',
#  '(011) 23513795 ',
#  '(011) 71555111 ',
#  '(011) 23561458 ',
#  'www.hotelgolfview.in',
#  '(0124) 4062984 4062985 ',
#  '(011) 45144444 ',
#  '(011) 41090202 ',
#  '(011) 45081841 45081842 ',
#  '(011) 25751324 25751208',
#  '(011) 40401100 ',
#  '(011) 41550999 ',
#  '(011) 26788499 26788599',
#  '(011) 23587999 ',
#  'www.pihotels.in',
#  '(011) 43586101 23519977 ',
#  '(011) 43101101 43101102 ',
#  '',
#  '(011) 49572222 ',
#  '(011) 26784665 26784666 ',
#  '(011) 41087732 41097732 ',
#  '(011) 25811192 25744106 ',
#  'www.hoteljageerpalace.com',
#  '(011) 42345331 ',
#  '(011) 42955555 28751704 ',
#  '(011) 48811111 ',
#  '(011) 23516912 23616388',
#  '(011) 23562415',
#  'www.hotelnoratan.com',
#  '(011) 28711701 28711703 ',
#  '(011) 26515151 ',
#  '(011) 42502509 42502760 ',
#  '(011) 45460000 43582610 ',
#  '(011) 40670000',
#  '(011) 23531125 23531126 ',
#  '',
#  '(011) 23585588',
#  '(011) 45053330 45053331 ',
#  '(011) 28713384 28713382 ',
#  '(011) 44212144 23683490 ',
#  '(011) 25743042 ',
#  '(011) 23588873 23588874',
#  '(011) 42301000 42301050',
#  '(011) 45012345 ',
#  '(011) 26933871 26933872 ',
#  '(011) 23561308 23584441',
#  '(0129) 2430262 ',
#  '(011) 40111111 ',
#  '(011) 46011111 ',
#  '(011) 42604200',
#  '',
#  '',
#  '',
#  '(011) 41315555 ',
#  '(0120) 4244817 ',
#  '(011) 40480000 ',
#  '(0120) 2536460 2533391 ',
#  'www.hotelsaharainternationaldeluxe.com',
#  '(011) 25733344 25733355 ',
#  '(0120) 4242600 ',
#  '(0129) 4083030 ',
#  '(011) 45678331 45678332',
#  '(011) 23519996 23519997 ',
#  '(011) 26526462 26526463 ',
#  '(0120) 4229806 ',
#  '(011) 45140000 25864601 ',
#  '(011) 23679801 23679800 ',
#  '(011) 49330000 28756310',
#  '(011) 26784092 26784093 ',
#  '',
#  '(011) 42503184',
#  '(011) 25751645 ',
#  '(011) 26144871 26146417 ',
#  '(011) 25730733 25732842 ',
#  '(011) 42503283 ',
#  '(011) 42503285 42502767 ',
#  '(011) 45871200 45871300 ',
#  '',
#  '(011) 45552682 ',
#  '(011) 41078888',
#  '(011) 45795442',
#  '(011) 23632801 23632802',
#  '(011) 23670985',
#  '(011) 23610334 ',
#  '(011) 26782410 26782411 ',
#  '',
#  '(011) 47821100 ',
#  'www.hotelwaves.com',
#  '(011) 41452172 41452174 ',
#  '(011) 41541304 41541305 ',
#  '(011) 41544553 ',
#  '(0120) 4659400 ',
#  'icsfoods.in',
#  '',
#  'www.indianaccent.com',
#  '(011) 28757726 ',
#  '(0124) 4655800 ',
#  '(011) 45769496 ',
#  '(011) 46072626 ',
#  '(011) 24350308 24350309 ',
#  '(011) 40582121 ',
#  '(011) 43337000 ',
#  '(0124) 4362121 ',
#  '(011) 23580523 ',
#  '(0129) 4292777 ',
#  '(011) 65028307',
#  '(011) 23264981 23269880 ',
#  '(011) 43437777 ',
#  '(011) 46603300 ',
#  '(0124) 4361141',
#  '(011) 26781572 26781573 ',
#  '(011) 49338800 49338888 ',
#  '(011) 41507014 ',
#  '(0120) 4554513 ',
#  '',
#  '(0124) 4887777 ',
#  '(011) 45019471 45019472',
#  '(0129) 2411110 ',
#  'www.mananregency.com',
#  '(011) 45064749 45046544 ',
#  '(011) 49664966 ',
#  '(011) 23681112 ',
#  '(011) 45129090 42139090 ',
#  '(011) 26872760 ',
#  '(011) 27052700 ',
#  '(011) 29847786 ',
#  '(011) 41000967 ',
#  '(011) 46208282',
#  '(0120) 4116679',
#  'noshi.in',
#  '(011) 26549700 ',
#  '(0120) 4284422 ',
#  '(011) 47781195 ',
#  '(0120) 6780000 ',
#  '(0120) 2450062 2450061',
#  '',
#  '(011) 27190728 ',
#  'www.corporatedhaba.com',
#  '(011) 43552148 ',
#  '(0124) 4948554 4956350',
#  '(011) 45173333',
#  '(011) 26526192 26526194 ',
#  '(011) 23611710 ',
#  '(011) 27035353 ',
#  '',
#  '(0124) 7151923 ',
#  '(011) 24652474 ',
#  '(0120) 4375000 ',
#  '(011) 26151228 ',
#  'www.rkvilla.com',
#  'www.roopresorts.com',
#  '(0124) 4222001 4222002',
#  '(011) 49818000 ',
#  'www.rudrakshaa.in',
#  '(011) 41032280',
#  '(0129) 4095000 ',
#  '(0124) 4382565 ',
#  '(0124) 4910100 ',
#  '(0124) 4303188 4303191',
#  '',
#  '(011) 45424542 ',
#  '(0120) 3355600 ',
#  '(0124) 3355600 ',
#  '(0124) 4812100 ',
#  'www.shantitravel.com',
#  '(011) 41573366 41573377 ',
#  '(011) 41068807 ',
#  '(011) 45000390 45000300 ',
#  '(011) 47008422 47008423',
#  '(0124) 2359250 ',
#  'sleepyowl.co',
#  'www.olivebarandkitchen.com',
#  '(011) 28753651 28753126 ',
#  'www.starlitsuites.com',
#  '(0124) 4283260 ',
#  '(011) 23381638',
#  'www.sunstarhospitality.com',
#  '',
#  '',
#  '(0120) 4206118 4206119',
#  'www.tasanaya.com',
#  '(011) 43300000 ',
#  '(011) 43300000 ',
#  '(0124) 4369808 ',
#  'www.tavishavilla.com',
#  '(011) 48184818 ',
#  '',
#  '(0124) 4367000 ',
#  '(011) 43652222 43652223 ',
#  '',
#  '(011) 40780780 ',
#  '(0124) 4880000',
#  '(011) 47060152',
#  '(011) 45531331 45531332 ',
#  '(0124) 4102900 4058000 ',
#  '(011) 41725200 41725201 ',
#  '(0120) 4231100 ',
#  '(011) 26560582 26969348 ',
#  '(011) 43043846 43043847 ',
#  '(011) 42131805 42131806 ',
#  '(0124) 4366767 4000082 ',
#  '(011) 41662900 26141849 ',
#  'www.thegoldengateresidency.com',
#  '(0124) 4200900',
#  '(011) 26853760 26858656 ',
#  'treebo.com',
#  '(0124) 4425000 ',
#  'www.trillionhotel.com',
#  '(011) 40833333 ',
#  '(011) 26779070 ',
#  '(011) 47707070 ',
#  'www.vmresidency.net',
#  '(0120) 6666900 ',
#  '(0124) 4222160 4222161 ',
#  '(011) 45871123',
#  '(0124) 2383481 4575700',
#  '(0129) 4290000 ',
#  '(011) 40511101 40511199 ',
#  '(011) 29536309 ',
#  '(011) 23261000 49091777 ',
#  '(011) 41502421 41502422',
#  '(011) 25753555 25754555 ',
#  '(011) 41315858 31907878 ']

# %%
import pandas as pd
df=pd.DataFrame()

# %%
df["Name"]=Name
df["Address"]=Add
df["Phone"]=Phone

# %%
df
# Out:
#                                                 Name  \
# 0    Vivanta by Taj - Surajkund (*****) (Taj (IHCL))
# 1                Vivanta by Taj, Dwarka (Taj (IHCL))
# 2           Wave Hospitality Pvt Ltd ( Holiday Inn )
# 3                               WelcomHeritage (ITC)
# 4                      WelcomHotel Dwarka, New Delhi
# ..                                               ...
# 353             VW Cuisines & Concepts Pvt Ltd (Fio)
# 354           WelcomHeritage Haveli Dharampura (ITC)
# 355                                  Welworth Hotels
# 356                                      Wood Castle
# 357         Xperience India Hotels & Resorts Pvt Ltd
#
#                                              Address                     Phone
# 0                      Address - Shooting Range Road            (0129) 4190000
# 1         Address - Sector 21 Metro Station Complex,           (011) 66003000
# 2                            Address - Asset Area 12           (011) 42222000
# 3          Address - 25, Shopping Centre, Basant Lok           (011) 46035500
# 4                    Address - Plot No.3, Sector-10,           (011) 42229222
# ..                                               ...                       ...
# 353                         Address - Epicuria Mall,           (011) 29536309
# 354                     Address - 2293, Gali Guliyan  (011) 23261000 49091777
# 355  Address - 7, Regal Building Behind Regal Cinema   (011) 41502421 41502422
# 356           Address - 8A/7G, W.E.A. Channa Market,  (011) 25753555 25754555
# 357        Address - F 210 D Old M B Road Lado Sarai  (011) 41315858 31907878
#
# [358 rows x 3 columns]

# %%
df.to_csv(r'C:\Users\sarve\Hotels In Delhi.csv', index = False)
