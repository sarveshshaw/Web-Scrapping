# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
Links=[]
#till 29
for i in range(1,29):
    url='https://www.fundoodata.com/citiesindustry/2/0/list-of-bfsi-companies-in-delhi-ncr?&pageno='+str(1)+'&tot_rows=551&total_results=551&no_of_offices=0'
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:50.0) Gecko/20100101Firefox/50.0'}
    source=requests.get(url, headers=headers)
    source.content
    soup=bs(source.content,'html.parser')
    results=soup.find_all('div',class_='search-result')
    for result in results:
        link=result.find('div',class_='heading')
        if link!=None:    
            Links.append(link.a['href'])

# %%
Name=[]
Add=[]
Phone=[]
for link in Links:
    page=requests.get(link)
    page.content
    subsoup=bs(page.content,'html.parser')
    subresult=subsoup.find('div',class_='search-page-right-pannel')
    if subresult!=None:
        name=subresult.find('div',class_='search-page-heading-red')
        Name.append(name.text.strip())
        no=subresult.find('div',class_='detail-line')
        if no!=None:
            ph=no.text.strip()
            no=ph.split("\n")
            number=no[0]
            Phone.append(number)
        else:
            Phone.append("NaN")
        tr=subresult.find('div',class_='search-page-heading-red').decompose()
        add=subresult.text.strip().split("\t")
        Add.append(add[0])

# %%
Name
# Out:
# ['IFCI Ltd (IFCI)',
#  'PNB Housing Finance Ltd',
#  'Power Finance Corporation Ltd',
#  'Punjab and Sind Bank',
#  'Punjab National Bank (PNB) (PNB)',
#  '',
#  'India Infrastructure Finance Company Ltd (IIFCL)',
#  'Max Life Insurance Company Ltd (Max)',
#  'One97 Communications Ltd ( Paytm )',
#  'Oriental Insurance Company Ltd',
#  'PTC India Financial Services Ltd',
#  'Satin Creditcare Network Ltd',
#  'Sindhu Trade Links Ltd',
#  'VLS Finance Ltd.',
#  'Access Financial Services consultancy Pvt Ltd',
#  'ACCURACY India',
#  'Actis Advisers Pvt Ltd',
#  'Allianz Partners India',
#  'Alpen Capital India Pvt Ltd',
#  'American Express Banking Corporation',
#  'IFCI Ltd (IFCI)',
#  'PNB Housing Finance Ltd',
#  'Power Finance Corporation Ltd',
#  'Punjab and Sind Bank',
#  'Punjab National Bank (PNB) (PNB)',
#  '',
#  'India Infrastructure Finance Company Ltd (IIFCL)',
#  'Max Life Insurance Company Ltd (Max)',
#  'One97 Communications Ltd ( Paytm )',
#  'Oriental Insurance Company Ltd',
#  'PTC India Financial Services Ltd',
#  'Satin Creditcare Network Ltd',
#  'Sindhu Trade Links Ltd',
#  'VLS Finance Ltd.',
#  'Access Financial Services consultancy Pvt Ltd',
#  'ACCURACY India',
#  'Actis Advisers Pvt Ltd',
#  'Allianz Partners India',
#  'Alpen Capital India Pvt Ltd',
#  'American Express Banking Corporation',
#  'IFCI Ltd (IFCI)',
#  'PNB Housing Finance Ltd',
#  'Power Finance Corporation Ltd',
#  'Punjab and Sind Bank',
#  'Punjab National Bank (PNB) (PNB)',
#  '',
#  'India Infrastructure Finance Company Ltd (IIFCL)',
#  'Max Life Insurance Company Ltd (Max)',
#  'One97 Communications Ltd ( Paytm )',
#  'Oriental Insurance Company Ltd',
#  'PTC India Financial Services Ltd',
#  'Satin Creditcare Network Ltd',
#  'Sindhu Trade Links Ltd',
#  'VLS Finance Ltd.',
#  'Access Financial Services consultancy Pvt Ltd',
#  'ACCURACY India',
#  'Actis Advisers Pvt Ltd',
#  'Allianz Partners India',
#  'Alpen Capital India Pvt Ltd',
#  'American Express Banking Corporation',
#  'IFCI Ltd (IFCI)',
#  'PNB Housing Finance Ltd',
#  'Power Finance Corporation Ltd',
#  'Punjab and Sind Bank',
#  'Punjab National Bank (PNB) (PNB)',
#  '',
#  'India Infrastructure Finance Company Ltd (IIFCL)',
#  'Max Life Insurance Company Ltd (Max)',
#  'One97 Communications Ltd ( Paytm )',
#  'Oriental Insurance Company Ltd',
#  'PTC India Financial Services Ltd',
#  'Satin Creditcare Network Ltd',
#  'Sindhu Trade Links Ltd',
#  'VLS Finance Ltd.',
#  'Access Financial Services consultancy Pvt Ltd',
#  'ACCURACY India',
#  'Actis Advisers Pvt Ltd',
#  'Allianz Partners India',
#  'Alpen Capital India Pvt Ltd',
#  'American Express Banking Corporation',
#  'IFCI Ltd (IFCI)',
#  'PNB Housing Finance Ltd',
#  'Power Finance Corporation Ltd',
#  'Punjab and Sind Bank',
#  'Punjab National Bank (PNB) (PNB)',
#  '',
#  'India Infrastructure Finance Company Ltd (IIFCL)',
#  'Max Life Insurance Company Ltd (Max)',
#  'One97 Communications Ltd ( Paytm )',
#  'Oriental Insurance Company Ltd',
#  'PTC India Financial Services Ltd',
#  'Satin Creditcare Network Ltd',
#  'Sindhu Trade Links Ltd',
#  'VLS Finance Ltd.',
#  'Access Financial Services consultancy Pvt Ltd',
#  'ACCURACY India',
#  'Actis Advisers Pvt Ltd',
#  'Allianz Partners India',
#  'Alpen Capital India Pvt Ltd',
#  'American Express Banking Corporation',
#  'IFCI Ltd (IFCI)',
#  'PNB Housing Finance Ltd',
#  'Power Finance Corporation Ltd',
#  'Punjab and Sind Bank',
#  'Punjab National Bank (PNB) (PNB)',
#  '',
#  'India Infrastructure Finance Company Ltd (IIFCL)',
#  'Max Life Insurance Company Ltd (Max)',
#  'One97 Communications Ltd ( Paytm )',
#  'Oriental Insurance Company Ltd',
#  'PTC India Financial Services Ltd',
#  'Satin Creditcare Network Ltd',
#  'Sindhu Trade Links Ltd',
#  'VLS Finance Ltd.',
#  'Access Financial Services consultancy Pvt Ltd',
#  'ACCURACY India',
#  'Actis Advisers Pvt Ltd',
#  'Allianz Partners India',
#  'Alpen Capital India Pvt Ltd',
#  'American Express Banking Corporation',
#  'IFCI Ltd (IFCI)',
#  'PNB Housing Finance Ltd',
#  'Power Finance Corporation Ltd',
#  'Punjab and Sind Bank',
#  'Punjab National Bank (PNB) (PNB)',
#  '',
#  'India Infrastructure Finance Company Ltd (IIFCL)',
#  'Max Life Insurance Company Ltd (Max)',
#  'One97 Communications Ltd ( Paytm )',
#  'Oriental Insurance Company Ltd',
#  'PTC India Financial Services Ltd',
#  'Satin Creditcare Network Ltd',
#  'Sindhu Trade Links Ltd',
#  'VLS Finance Ltd.',
#  'Access Financial Services consultancy Pvt Ltd',
#  'ACCURACY India',
#  'Actis Advisers Pvt Ltd',
#  'Allianz Partners India',
#  'Alpen Capital India Pvt Ltd',
#  'American Express Banking Corporation',
#  'IFCI Ltd (IFCI)',
#  'PNB Housing Finance Ltd',
#  'Power Finance Corporation Ltd',
#  'Punjab and Sind Bank',
#  'Punjab National Bank (PNB) (PNB)',
#  '',
#  'India Infrastructure Finance Company Ltd (IIFCL)',
#  'Max Life Insurance Company Ltd (Max)',
#  'One97 Communications Ltd ( Paytm )',
#  'Oriental Insurance Company Ltd',
#  'PTC India Financial Services Ltd',
#  'Satin Creditcare Network Ltd',
#  'Sindhu Trade Links Ltd',
#  'VLS Finance Ltd.',
#  'Access Financial Services consultancy Pvt Ltd',
#  'ACCURACY India',
#  'Actis Advisers Pvt Ltd',
#  'Allianz Partners India',
#  'Alpen Capital India Pvt Ltd',
#  'American Express Banking Corporation',
#  'IFCI Ltd (IFCI)',
#  'PNB Housing Finance Ltd',
#  'Power Finance Corporation Ltd',
#  'Punjab and Sind Bank',
#  'Punjab National Bank (PNB) (PNB)',
#  '',
#  'India Infrastructure Finance Company Ltd (IIFCL)',
#  'Max Life Insurance Company Ltd (Max)',
#  'One97 Communications Ltd ( Paytm )',
#  'Oriental Insurance Company Ltd',
#  'PTC India Financial Services Ltd',
#  'Satin Creditcare Network Ltd',
#  'Sindhu Trade Links Ltd',
#  'VLS Finance Ltd.',
#  'Access Financial Services consultancy Pvt Ltd',
#  'ACCURACY India',
#  'Actis Advisers Pvt Ltd',
#  'Allianz Partners India',
#  'Alpen Capital India Pvt Ltd',
#  'American Express Banking Corporation',
#  'IFCI Ltd (IFCI)',
#  'PNB Housing Finance Ltd',
#  'Power Finance Corporation Ltd',
#  'Punjab and Sind Bank',
#  'Punjab National Bank (PNB) (PNB)',
#  '',
#  'India Infrastructure Finance Company Ltd (IIFCL)',
#  'Max Life Insurance Company Ltd (Max)',
#  'One97 Communications Ltd ( Paytm )',
#  'Oriental Insurance Company Ltd',
#  'PTC India Financial Services Ltd',
#  'Satin Creditcare Network Ltd',
#  'Sindhu Trade Links Ltd',
#  'VLS Finance Ltd.',
#  'Access Financial Services consultancy Pvt Ltd',
#  'ACCURACY India',
#  'Actis Advisers Pvt Ltd',
#  'Allianz Partners India',
#  'Alpen Capital India Pvt Ltd',
#  'American Express Banking Corporation',
#  'IFCI Ltd (IFCI)',
#  'PNB Housing Finance Ltd',
#  'Power Finance Corporation Ltd',
#  'Punjab and Sind Bank',
#  'Punjab National Bank (PNB) (PNB)',
#  '',
#  'India Infrastructure Finance Company Ltd (IIFCL)',
#  'Max Life Insurance Company Ltd (Max)',
#  'One97 Communications Ltd ( Paytm )',
#  'Oriental Insurance Company Ltd',
#  'PTC India Financial Services Ltd',
#  'Satin Creditcare Network Ltd',
#  'Sindhu Trade Links Ltd',
#  'VLS Finance Ltd.',
#  'Access Financial Services consultancy Pvt Ltd',
#  'ACCURACY India',
#  'Actis Advisers Pvt Ltd',
#  'Allianz Partners India',
#  'Alpen Capital India Pvt Ltd',
#  'American Express Banking Corporation',
#  'IFCI Ltd (IFCI)',
#  'PNB Housing Finance Ltd',
#  'Power Finance Corporation Ltd',
#  'Punjab and Sind Bank',
#  'Punjab National Bank (PNB) (PNB)',
#  '',
#  'India Infrastructure Finance Company Ltd (IIFCL)',
#  'Max Life Insurance Company Ltd (Max)',
#  'One97 Communications Ltd ( Paytm )',
#  'Oriental Insurance Company Ltd',
#  'PTC India Financial Services Ltd',
#  'Satin Creditcare Network Ltd',
#  'Sindhu Trade Links Ltd',
#  'VLS Finance Ltd.',
#  'Access Financial Services consultancy Pvt Ltd',
#  'ACCURACY India',
#  'Actis Advisers Pvt Ltd',
#  'Allianz Partners India',
#  'Alpen Capital India Pvt Ltd',
#  'American Express Banking Corporation',
#  'IFCI Ltd (IFCI)',
#  'PNB Housing Finance Ltd',
#  'Power Finance Corporation Ltd',
#  'Punjab and Sind Bank',
#  'Punjab National Bank (PNB) (PNB)',
#  '',
#  'India Infrastructure Finance Company Ltd (IIFCL)',
#  'Max Life Insurance Company Ltd (Max)',
#  'One97 Communications Ltd ( Paytm )',
#  'Oriental Insurance Company Ltd',
#  'PTC India Financial Services Ltd',
#  'Satin Creditcare Network Ltd',
#  'Sindhu Trade Links Ltd',
#  'VLS Finance Ltd.',
#  'Access Financial Services consultancy Pvt Ltd',
#  'ACCURACY India',
#  'Actis Advisers Pvt Ltd',
#  'Allianz Partners India',
#  'Alpen Capital India Pvt Ltd',
#  'American Express Banking Corporation']

# %%
Add
# Out:
# ['Address - IFCI Tower, 61 Nehru Place',
#  'Address - 9th Floor ,Antriksh Bhawan,22 K G',
#  'Address - Urjanidhi, 1 Barakhamba Lane, Connaught Place',
#  'Address - Bank House,21, Rajindra Place',
#  'Address - Plot No 4, Sector -10 Dwarka',
#  'The updated information of this company is currently unavailable. For other companies please visit Advance Search.\n',
#  'Address - 5th Floor, Block 2, Plate A & B, NBCC Tower,',
#  'Address - 11th Floor, DLF Square Building, Jacaranda Marg, Phase II',
#  'Address - B 121, Sector 5',
#  'Address - Oriental House, A-25/27, Asaf Ali Road',
#  'Address - 7th Floor Telephone Exchange Building',
#  'Address - Floor 1 & 3, Plot No -97,',
#  'Address - 16A, 3RD Floor, Najafgarh Road,',
#  'Address - No. 13, 2nd Floor, Sant Nagar, East Of Kailash',
#  'Address - F 15, 1st Floor,Sector 8',
#  'Address - Level 17 Building No 5 Tower A',
#  'Address - The Mira Corporate Suites, D Block, Ground Floor,',
#  'Address - 1st Floor, DLF Square',
#  'Address - Office No 630 6th floor, Le Meridien Commercial Tower',
#  'Address - Cyber City, Tower C, DLF Bldg No.8,',
#  'Address - IFCI Tower, 61 Nehru Place',
#  'Address - 9th Floor ,Antriksh Bhawan,22 K G',
#  'Address - Urjanidhi, 1 Barakhamba Lane, Connaught Place',
#  'Address - Bank House,21, Rajindra Place',
#  'Address - Plot No 4, Sector -10 Dwarka',
#  'The updated information of this company is currently unavailable. For other companies please visit Advance Search.\n',
#  'Address - 5th Floor, Block 2, Plate A & B, NBCC Tower,',
#  'Address - 11th Floor, DLF Square Building, Jacaranda Marg, Phase II',
#  'Address - B 121, Sector 5',
#  'Address - Oriental House, A-25/27, Asaf Ali Road',
#  'Address - 7th Floor Telephone Exchange Building',
#  'Address - Floor 1 & 3, Plot No -97,',
#  'Address - 16A, 3RD Floor, Najafgarh Road,',
#  'Address - No. 13, 2nd Floor, Sant Nagar, East Of Kailash',
#  'Address - F 15, 1st Floor,Sector 8',
#  'Address - Level 17 Building No 5 Tower A',
#  'Address - The Mira Corporate Suites, D Block, Ground Floor,',
#  'Address - 1st Floor, DLF Square',
#  'Address - Office No 630 6th floor, Le Meridien Commercial Tower',
#  'Address - Cyber City, Tower C, DLF Bldg No.8,',
#  'Address - IFCI Tower, 61 Nehru Place',
#  'Address - 9th Floor ,Antriksh Bhawan,22 K G',
#  'Address - Urjanidhi, 1 Barakhamba Lane, Connaught Place',
#  'Address - Bank House,21, Rajindra Place',
#  'Address - Plot No 4, Sector -10 Dwarka',
#  'The updated information of this company is currently unavailable. For other companies please visit Advance Search.\n',
#  'Address - 5th Floor, Block 2, Plate A & B, NBCC Tower,',
#  'Address - 11th Floor, DLF Square Building, Jacaranda Marg, Phase II',
#  'Address - B 121, Sector 5',
#  'Address - Oriental House, A-25/27, Asaf Ali Road',
#  'Address - 7th Floor Telephone Exchange Building',
#  'Address - Floor 1 & 3, Plot No -97,',
#  'Address - 16A, 3RD Floor, Najafgarh Road,',
#  'Address - No. 13, 2nd Floor, Sant Nagar, East Of Kailash',
#  'Address - F 15, 1st Floor,Sector 8',
#  'Address - Level 17 Building No 5 Tower A',
#  'Address - The Mira Corporate Suites, D Block, Ground Floor,',
#  'Address - 1st Floor, DLF Square',
#  'Address - Office No 630 6th floor, Le Meridien Commercial Tower',
#  'Address - Cyber City, Tower C, DLF Bldg No.8,',
#  'Address - IFCI Tower, 61 Nehru Place',
#  'Address - 9th Floor ,Antriksh Bhawan,22 K G',
#  'Address - Urjanidhi, 1 Barakhamba Lane, Connaught Place',
#  'Address - Bank House,21, Rajindra Place',
#  'Address - Plot No 4, Sector -10 Dwarka',
#  'The updated information of this company is currently unavailable. For other companies please visit Advance Search.\n',
#  'Address - 5th Floor, Block 2, Plate A & B, NBCC Tower,',
#  'Address - 11th Floor, DLF Square Building, Jacaranda Marg, Phase II',
#  'Address - B 121, Sector 5',
#  'Address - Oriental House, A-25/27, Asaf Ali Road',
#  'Address - 7th Floor Telephone Exchange Building',
#  'Address - Floor 1 & 3, Plot No -97,',
#  'Address - 16A, 3RD Floor, Najafgarh Road,',
#  'Address - No. 13, 2nd Floor, Sant Nagar, East Of Kailash',
#  'Address - F 15, 1st Floor,Sector 8',
#  'Address - Level 17 Building No 5 Tower A',
#  'Address - The Mira Corporate Suites, D Block, Ground Floor,',
#  'Address - 1st Floor, DLF Square',
#  'Address - Office No 630 6th floor, Le Meridien Commercial Tower',
#  'Address - Cyber City, Tower C, DLF Bldg No.8,',
#  'Address - IFCI Tower, 61 Nehru Place',
#  'Address - 9th Floor ,Antriksh Bhawan,22 K G',
#  'Address - Urjanidhi, 1 Barakhamba Lane, Connaught Place',
#  'Address - Bank House,21, Rajindra Place',
#  'Address - Plot No 4, Sector -10 Dwarka',
#  'The updated information of this company is currently unavailable. For other companies please visit Advance Search.\n',
#  'Address - 5th Floor, Block 2, Plate A & B, NBCC Tower,',
#  'Address - 11th Floor, DLF Square Building, Jacaranda Marg, Phase II',
#  'Address - B 121, Sector 5',
#  'Address - Oriental House, A-25/27, Asaf Ali Road',
#  'Address - 7th Floor Telephone Exchange Building',
#  'Address - Floor 1 & 3, Plot No -97,',
#  'Address - 16A, 3RD Floor, Najafgarh Road,',
#  'Address - No. 13, 2nd Floor, Sant Nagar, East Of Kailash',
#  'Address - F 15, 1st Floor,Sector 8',
#  'Address - Level 17 Building No 5 Tower A',
#  'Address - The Mira Corporate Suites, D Block, Ground Floor,',
#  'Address - 1st Floor, DLF Square',
#  'Address - Office No 630 6th floor, Le Meridien Commercial Tower',
#  'Address - Cyber City, Tower C, DLF Bldg No.8,',
#  'Address - IFCI Tower, 61 Nehru Place',
#  'Address - 9th Floor ,Antriksh Bhawan,22 K G',
#  'Address - Urjanidhi, 1 Barakhamba Lane, Connaught Place',
#  'Address - Bank House,21, Rajindra Place',
#  'Address - Plot No 4, Sector -10 Dwarka',
#  'The updated information of this company is currently unavailable. For other companies please visit Advance Search.\n',
#  'Address - 5th Floor, Block 2, Plate A & B, NBCC Tower,',
#  'Address - 11th Floor, DLF Square Building, Jacaranda Marg, Phase II',
#  'Address - B 121, Sector 5',
#  'Address - Oriental House, A-25/27, Asaf Ali Road',
#  'Address - 7th Floor Telephone Exchange Building',
#  'Address - Floor 1 & 3, Plot No -97,',
#  'Address - 16A, 3RD Floor, Najafgarh Road,',
#  'Address - No. 13, 2nd Floor, Sant Nagar, East Of Kailash',
#  'Address - F 15, 1st Floor,Sector 8',
#  'Address - Level 17 Building No 5 Tower A',
#  'Address - The Mira Corporate Suites, D Block, Ground Floor,',
#  'Address - 1st Floor, DLF Square',
#  'Address - Office No 630 6th floor, Le Meridien Commercial Tower',
#  'Address - Cyber City, Tower C, DLF Bldg No.8,',
#  'Address - IFCI Tower, 61 Nehru Place',
#  'Address - 9th Floor ,Antriksh Bhawan,22 K G',
#  'Address - Urjanidhi, 1 Barakhamba Lane, Connaught Place',
#  'Address - Bank House,21, Rajindra Place',
#  'Address - Plot No 4, Sector -10 Dwarka',
#  'The updated information of this company is currently unavailable. For other companies please visit Advance Search.\n',
#  'Address - 5th Floor, Block 2, Plate A & B, NBCC Tower,',
#  'Address - 11th Floor, DLF Square Building, Jacaranda Marg, Phase II',
#  'Address - B 121, Sector 5',
#  'Address - Oriental House, A-25/27, Asaf Ali Road',
#  'Address - 7th Floor Telephone Exchange Building',
#  'Address - Floor 1 & 3, Plot No -97,',
#  'Address - 16A, 3RD Floor, Najafgarh Road,',
#  'Address - No. 13, 2nd Floor, Sant Nagar, East Of Kailash',
#  'Address - F 15, 1st Floor,Sector 8',
#  'Address - Level 17 Building No 5 Tower A',
#  'Address - The Mira Corporate Suites, D Block, Ground Floor,',
#  'Address - 1st Floor, DLF Square',
#  'Address - Office No 630 6th floor, Le Meridien Commercial Tower',
#  'Address - Cyber City, Tower C, DLF Bldg No.8,',
#  'Address - IFCI Tower, 61 Nehru Place',
#  'Address - 9th Floor ,Antriksh Bhawan,22 K G',
#  'Address - Urjanidhi, 1 Barakhamba Lane, Connaught Place',
#  'Address - Bank House,21, Rajindra Place',
#  'Address - Plot No 4, Sector -10 Dwarka',
#  'The updated information of this company is currently unavailable. For other companies please visit Advance Search.\n',
#  'Address - 5th Floor, Block 2, Plate A & B, NBCC Tower,',
#  'Address - 11th Floor, DLF Square Building, Jacaranda Marg, Phase II',
#  'Address - B 121, Sector 5',
#  'Address - Oriental House, A-25/27, Asaf Ali Road',
#  'Address - 7th Floor Telephone Exchange Building',
#  'Address - Floor 1 & 3, Plot No -97,',
#  'Address - 16A, 3RD Floor, Najafgarh Road,',
#  'Address - No. 13, 2nd Floor, Sant Nagar, East Of Kailash',
#  'Address - F 15, 1st Floor,Sector 8',
#  'Address - Level 17 Building No 5 Tower A',
#  'Address - The Mira Corporate Suites, D Block, Ground Floor,',
#  'Address - 1st Floor, DLF Square',
#  'Address - Office No 630 6th floor, Le Meridien Commercial Tower',
#  'Address - Cyber City, Tower C, DLF Bldg No.8,',
#  'Address - IFCI Tower, 61 Nehru Place',
#  'Address - 9th Floor ,Antriksh Bhawan,22 K G',
#  'Address - Urjanidhi, 1 Barakhamba Lane, Connaught Place',
#  'Address - Bank House,21, Rajindra Place',
#  'Address - Plot No 4, Sector -10 Dwarka',
#  'The updated information of this company is currently unavailable. For other companies please visit Advance Search.\n',
#  'Address - 5th Floor, Block 2, Plate A & B, NBCC Tower,',
#  'Address - 11th Floor, DLF Square Building, Jacaranda Marg, Phase II',
#  'Address - B 121, Sector 5',
#  'Address - Oriental House, A-25/27, Asaf Ali Road',
#  'Address - 7th Floor Telephone Exchange Building',
#  'Address - Floor 1 & 3, Plot No -97,',
#  'Address - 16A, 3RD Floor, Najafgarh Road,',
#  'Address - No. 13, 2nd Floor, Sant Nagar, East Of Kailash',
#  'Address - F 15, 1st Floor,Sector 8',
#  'Address - Level 17 Building No 5 Tower A',
#  'Address - The Mira Corporate Suites, D Block, Ground Floor,',
#  'Address - 1st Floor, DLF Square',
#  'Address - Office No 630 6th floor, Le Meridien Commercial Tower',
#  'Address - Cyber City, Tower C, DLF Bldg No.8,',
#  'Address - IFCI Tower, 61 Nehru Place',
#  'Address - 9th Floor ,Antriksh Bhawan,22 K G',
#  'Address - Urjanidhi, 1 Barakhamba Lane, Connaught Place',
#  'Address - Bank House,21, Rajindra Place',
#  'Address - Plot No 4, Sector -10 Dwarka',
#  'The updated information of this company is currently unavailable. For other companies please visit Advance Search.\n',
#  'Address - 5th Floor, Block 2, Plate A & B, NBCC Tower,',
#  'Address - 11th Floor, DLF Square Building, Jacaranda Marg, Phase II',
#  'Address - B 121, Sector 5',
#  'Address - Oriental House, A-25/27, Asaf Ali Road',
#  'Address - 7th Floor Telephone Exchange Building',
#  'Address - Floor 1 & 3, Plot No -97,',
#  'Address - 16A, 3RD Floor, Najafgarh Road,',
#  'Address - No. 13, 2nd Floor, Sant Nagar, East Of Kailash',
#  'Address - F 15, 1st Floor,Sector 8',
#  'Address - Level 17 Building No 5 Tower A',
#  'Address - The Mira Corporate Suites, D Block, Ground Floor,',
#  'Address - 1st Floor, DLF Square',
#  'Address - Office No 630 6th floor, Le Meridien Commercial Tower',
#  'Address - Cyber City, Tower C, DLF Bldg No.8,',
#  'Address - IFCI Tower, 61 Nehru Place',
#  'Address - 9th Floor ,Antriksh Bhawan,22 K G',
#  'Address - Urjanidhi, 1 Barakhamba Lane, Connaught Place',
#  'Address - Bank House,21, Rajindra Place',
#  'Address - Plot No 4, Sector -10 Dwarka',
#  'The updated information of this company is currently unavailable. For other companies please visit Advance Search.\n',
#  'Address - 5th Floor, Block 2, Plate A & B, NBCC Tower,',
#  'Address - 11th Floor, DLF Square Building, Jacaranda Marg, Phase II',
#  'Address - B 121, Sector 5',
#  'Address - Oriental House, A-25/27, Asaf Ali Road',
#  'Address - 7th Floor Telephone Exchange Building',
#  'Address - Floor 1 & 3, Plot No -97,',
#  'Address - 16A, 3RD Floor, Najafgarh Road,',
#  'Address - No. 13, 2nd Floor, Sant Nagar, East Of Kailash',
#  'Address - F 15, 1st Floor,Sector 8',
#  'Address - Level 17 Building No 5 Tower A',
#  'Address - The Mira Corporate Suites, D Block, Ground Floor,',
#  'Address - 1st Floor, DLF Square',
#  'Address - Office No 630 6th floor, Le Meridien Commercial Tower',
#  'Address - Cyber City, Tower C, DLF Bldg No.8,',
#  'Address - IFCI Tower, 61 Nehru Place',
#  'Address - 9th Floor ,Antriksh Bhawan,22 K G',
#  'Address - Urjanidhi, 1 Barakhamba Lane, Connaught Place',
#  'Address - Bank House,21, Rajindra Place',
#  'Address - Plot No 4, Sector -10 Dwarka',
#  'The updated information of this company is currently unavailable. For other companies please visit Advance Search.\n',
#  'Address - 5th Floor, Block 2, Plate A & B, NBCC Tower,',
#  'Address - 11th Floor, DLF Square Building, Jacaranda Marg, Phase II',
#  'Address - B 121, Sector 5',
#  'Address - Oriental House, A-25/27, Asaf Ali Road',
#  'Address - 7th Floor Telephone Exchange Building',
#  'Address - Floor 1 & 3, Plot No -97,',
#  'Address - 16A, 3RD Floor, Najafgarh Road,',
#  'Address - No. 13, 2nd Floor, Sant Nagar, East Of Kailash',
#  'Address - F 15, 1st Floor,Sector 8',
#  'Address - Level 17 Building No 5 Tower A',
#  'Address - The Mira Corporate Suites, D Block, Ground Floor,',
#  'Address - 1st Floor, DLF Square',
#  'Address - Office No 630 6th floor, Le Meridien Commercial Tower',
#  'Address - Cyber City, Tower C, DLF Bldg No.8,',
#  'Address - IFCI Tower, 61 Nehru Place',
#  'Address - 9th Floor ,Antriksh Bhawan,22 K G',
#  'Address - Urjanidhi, 1 Barakhamba Lane, Connaught Place',
#  'Address - Bank House,21, Rajindra Place',
#  'Address - Plot No 4, Sector -10 Dwarka',
#  'The updated information of this company is currently unavailable. For other companies please visit Advance Search.\n',
#  'Address - 5th Floor, Block 2, Plate A & B, NBCC Tower,',
#  'Address - 11th Floor, DLF Square Building, Jacaranda Marg, Phase II',
#  'Address - B 121, Sector 5',
#  'Address - Oriental House, A-25/27, Asaf Ali Road',
#  'Address - 7th Floor Telephone Exchange Building',
#  'Address - Floor 1 & 3, Plot No -97,',
#  'Address - 16A, 3RD Floor, Najafgarh Road,',
#  'Address - No. 13, 2nd Floor, Sant Nagar, East Of Kailash',
#  'Address - F 15, 1st Floor,Sector 8',
#  'Address - Level 17 Building No 5 Tower A',
#  'Address - The Mira Corporate Suites, D Block, Ground Floor,',
#  'Address - 1st Floor, DLF Square',
#  'Address - Office No 630 6th floor, Le Meridien Commercial Tower',
#  'Address - Cyber City, Tower C, DLF Bldg No.8,']

# %%
Phone
# Out:
# ['(011) 41732000 41732523 ',
#  '(011) 23357171 23357172 ',
#  '(011) 23456000 23456001 ',
#  '(011) 25723872 25720849 ',
#  '(011) 28044907 28075000 ',
#  '',
#  '(011) 24662777 ',
#  '(0124) 4121500 ',
#  '(0120) 4770116 4770770 ',
#  '(011) 43659309 23264168 ',
#  '(011) 41659500 26737300 ',
#  '(0124) 4715400 ',
#  '(011) 47634400 ',
#  '(011) 46656666 41553082 ',
#  '(0120) 4681100 ',
#  '(0124) 4887000 ',
#  '(011) 66157200 ',
#  '(0124) 4343800 ',
#  '(011) 46444000 ',
#  '(0124) 4190699 ',
#  '(011) 41732000 41732523 ',
#  '(011) 23357171 23357172 ',
#  '(011) 23456000 23456001 ',
#  '(011) 25723872 25720849 ',
#  '(011) 28044907 28075000 ',
#  '',
#  '(011) 24662777 ',
#  '(0124) 4121500 ',
#  '(0120) 4770116 4770770 ',
#  '(011) 43659309 23264168 ',
#  '(011) 41659500 26737300 ',
#  '(0124) 4715400 ',
#  '(011) 47634400 ',
#  '(011) 46656666 41553082 ',
#  '(0120) 4681100 ',
#  '(0124) 4887000 ',
#  '(011) 66157200 ',
#  '(0124) 4343800 ',
#  '(011) 46444000 ',
#  '(0124) 4190699 ',
#  '(011) 41732000 41732523 ',
#  '(011) 23357171 23357172 ',
#  '(011) 23456000 23456001 ',
#  '(011) 25723872 25720849 ',
#  '(011) 28044907 28075000 ',
#  '',
#  '(011) 24662777 ',
#  '(0124) 4121500 ',
#  '(0120) 4770116 4770770 ',
#  '(011) 43659309 23264168 ',
#  '(011) 41659500 26737300 ',
#  '(0124) 4715400 ',
#  '(011) 47634400 ',
#  '(011) 46656666 41553082 ',
#  '(0120) 4681100 ',
#  '(0124) 4887000 ',
#  '(011) 66157200 ',
#  '(0124) 4343800 ',
#  '(011) 46444000 ',
#  '(0124) 4190699 ',
#  '(011) 41732000 41732523 ',
#  '(011) 23357171 23357172 ',
#  '(011) 23456000 23456001 ',
#  '(011) 25723872 25720849 ',
#  '(011) 28044907 28075000 ',
#  '',
#  '(011) 24662777 ',
#  '(0124) 4121500 ',
#  '(0120) 4770116 4770770 ',
#  '(011) 43659309 23264168 ',
#  '(011) 41659500 26737300 ',
#  '(0124) 4715400 ',
#  '(011) 47634400 ',
#  '(011) 46656666 41553082 ',
#  '(0120) 4681100 ',
#  '(0124) 4887000 ',
#  '(011) 66157200 ',
#  '(0124) 4343800 ',
#  '(011) 46444000 ',
#  '(0124) 4190699 ',
#  '(011) 41732000 41732523 ',
#  '(011) 23357171 23357172 ',
#  '(011) 23456000 23456001 ',
#  '(011) 25723872 25720849 ',
#  '(011) 28044907 28075000 ',
#  '',
#  '(011) 24662777 ',
#  '(0124) 4121500 ',
#  '(0120) 4770116 4770770 ',
#  '(011) 43659309 23264168 ',
#  '(011) 41659500 26737300 ',
#  '(0124) 4715400 ',
#  '(011) 47634400 ',
#  '(011) 46656666 41553082 ',
#  '(0120) 4681100 ',
#  '(0124) 4887000 ',
#  '(011) 66157200 ',
#  '(0124) 4343800 ',
#  '(011) 46444000 ',
#  '(0124) 4190699 ',
#  '(011) 41732000 41732523 ',
#  '(011) 23357171 23357172 ',
#  '(011) 23456000 23456001 ',
#  '(011) 25723872 25720849 ',
#  '(011) 28044907 28075000 ',
#  '',
#  '(011) 24662777 ',
#  '(0124) 4121500 ',
#  '(0120) 4770116 4770770 ',
#  '(011) 43659309 23264168 ',
#  '(011) 41659500 26737300 ',
#  '(0124) 4715400 ',
#  '(011) 47634400 ',
#  '(011) 46656666 41553082 ',
#  '(0120) 4681100 ',
#  '(0124) 4887000 ',
#  '(011) 66157200 ',
#  '(0124) 4343800 ',
#  '(011) 46444000 ',
#  '(0124) 4190699 ',
#  '(011) 41732000 41732523 ',
#  '(011) 23357171 23357172 ',
#  '(011) 23456000 23456001 ',
#  '(011) 25723872 25720849 ',
#  '(011) 28044907 28075000 ',
#  '',
#  '(011) 24662777 ',
#  '(0124) 4121500 ',
#  '(0120) 4770116 4770770 ',
#  '(011) 43659309 23264168 ',
#  '(011) 41659500 26737300 ',
#  '(0124) 4715400 ',
#  '(011) 47634400 ',
#  '(011) 46656666 41553082 ',
#  '(0120) 4681100 ',
#  '(0124) 4887000 ',
#  '(011) 66157200 ',
#  '(0124) 4343800 ',
#  '(011) 46444000 ',
#  '(0124) 4190699 ',
#  '(011) 41732000 41732523 ',
#  '(011) 23357171 23357172 ',
#  '(011) 23456000 23456001 ',
#  '(011) 25723872 25720849 ',
#  '(011) 28044907 28075000 ',
#  '',
#  '(011) 24662777 ',
#  '(0124) 4121500 ',
#  '(0120) 4770116 4770770 ',
#  '(011) 43659309 23264168 ',
#  '(011) 41659500 26737300 ',
#  '(0124) 4715400 ',
#  '(011) 47634400 ',
#  '(011) 46656666 41553082 ',
#  '(0120) 4681100 ',
#  '(0124) 4887000 ',
#  '(011) 66157200 ',
#  '(0124) 4343800 ',
#  '(011) 46444000 ',
#  '(0124) 4190699 ',
#  '(011) 41732000 41732523 ',
#  '(011) 23357171 23357172 ',
#  '(011) 23456000 23456001 ',
#  '(011) 25723872 25720849 ',
#  '(011) 28044907 28075000 ',
#  '',
#  '(011) 24662777 ',
#  '(0124) 4121500 ',
#  '(0120) 4770116 4770770 ',
#  '(011) 43659309 23264168 ',
#  '(011) 41659500 26737300 ',
#  '(0124) 4715400 ',
#  '(011) 47634400 ',
#  '(011) 46656666 41553082 ',
#  '(0120) 4681100 ',
#  '(0124) 4887000 ',
#  '(011) 66157200 ',
#  '(0124) 4343800 ',
#  '(011) 46444000 ',
#  '(0124) 4190699 ',
#  '(011) 41732000 41732523 ',
#  '(011) 23357171 23357172 ',
#  '(011) 23456000 23456001 ',
#  '(011) 25723872 25720849 ',
#  '(011) 28044907 28075000 ',
#  '',
#  '(011) 24662777 ',
#  '(0124) 4121500 ',
#  '(0120) 4770116 4770770 ',
#  '(011) 43659309 23264168 ',
#  '(011) 41659500 26737300 ',
#  '(0124) 4715400 ',
#  '(011) 47634400 ',
#  '(011) 46656666 41553082 ',
#  '(0120) 4681100 ',
#  '(0124) 4887000 ',
#  '(011) 66157200 ',
#  '(0124) 4343800 ',
#  '(011) 46444000 ',
#  '(0124) 4190699 ',
#  '(011) 41732000 41732523 ',
#  '(011) 23357171 23357172 ',
#  '(011) 23456000 23456001 ',
#  '(011) 25723872 25720849 ',
#  '(011) 28044907 28075000 ',
#  '',
#  '(011) 24662777 ',
#  '(0124) 4121500 ',
#  '(0120) 4770116 4770770 ',
#  '(011) 43659309 23264168 ',
#  '(011) 41659500 26737300 ',
#  '(0124) 4715400 ',
#  '(011) 47634400 ',
#  '(011) 46656666 41553082 ',
#  '(0120) 4681100 ',
#  '(0124) 4887000 ',
#  '(011) 66157200 ',
#  '(0124) 4343800 ',
#  '(011) 46444000 ',
#  '(0124) 4190699 ',
#  '(011) 41732000 41732523 ',
#  '(011) 23357171 23357172 ',
#  '(011) 23456000 23456001 ',
#  '(011) 25723872 25720849 ',
#  '(011) 28044907 28075000 ',
#  '',
#  '(011) 24662777 ',
#  '(0124) 4121500 ',
#  '(0120) 4770116 4770770 ',
#  '(011) 43659309 23264168 ',
#  '(011) 41659500 26737300 ',
#  '(0124) 4715400 ',
#  '(011) 47634400 ',
#  '(011) 46656666 41553082 ',
#  '(0120) 4681100 ',
#  '(0124) 4887000 ',
#  '(011) 66157200 ',
#  '(0124) 4343800 ',
#  '(011) 46444000 ',
#  '(0124) 4190699 ',
#  '(011) 41732000 41732523 ',
#  '(011) 23357171 23357172 ',
#  '(011) 23456000 23456001 ',
#  '(011) 25723872 25720849 ',
#  '(011) 28044907 28075000 ',
#  '',
#  '(011) 24662777 ',
#  '(0124) 4121500 ',
#  '(0120) 4770116 4770770 ',
#  '(011) 43659309 23264168 ',
#  '(011) 41659500 26737300 ',
#  '(0124) 4715400 ',
#  '(011) 47634400 ',
#  '(011) 46656666 41553082 ',
#  '(0120) 4681100 ',
#  '(0124) 4887000 ',
#  '(011) 66157200 ',
#  '(0124) 4343800 ',
#  '(011) 46444000 ',
#  '(0124) 4190699 ']

# %%
import pandas as pd
df=pd.DataFrame()

# %%
df["Name"]=Name
df["Address"]=Add
df["Phone"]=Phone

# %%
df
# Out:
#                                      Name  \
# 0                         IFCI Ltd (IFCI)
# 1                 PNB Housing Finance Ltd
# 2           Power Finance Corporation Ltd
# 3                    Punjab and Sind Bank
# 4        Punjab National Bank (PNB) (PNB)
# ..                                    ...
# 255                        ACCURACY India
# 256                Actis Advisers Pvt Ltd
# 257                Allianz Partners India
# 258           Alpen Capital India Pvt Ltd
# 259  American Express Banking Corporation
#
#                                                Address  \
# 0                 Address - IFCI Tower, 61 Nehru Place
# 1          Address - 9th Floor ,Antriksh Bhawan,22 K G
# 2    Address - Urjanidhi, 1 Barakhamba Lane, Connau...
# 3              Address - Bank House,21, Rajindra Place
# 4               Address - Plot No 4, Sector -10 Dwarka
# ..                                                 ...
# 255           Address - Level 17 Building No 5 Tower A
# 256  Address - The Mira Corporate Suites, D Block, ...
# 257                    Address - 1st Floor, DLF Square
# 258  Address - Office No 630 6th floor, Le Meridien...
# 259      Address - Cyber City, Tower C, DLF Bldg No.8,
#
#                         Phone
# 0    (011) 41732000 41732523
# 1    (011) 23357171 23357172
# 2    (011) 23456000 23456001
# 3    (011) 25723872 25720849
# 4    (011) 28044907 28075000
# ..                        ...
# 255           (0124) 4887000
# 256           (011) 66157200
# 257           (0124) 4343800
# 258           (011) 46444000
# 259           (0124) 4190699
#
# [260 rows x 3 columns]

# %%
df.to_csv(r'C:\Users\sarve\Banks In Delhi.csv', index = False)
